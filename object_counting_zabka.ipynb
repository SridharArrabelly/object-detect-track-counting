# %% [markdown]
# #### 0. Setup
#
# Pip install `ultralytics` and [dependencies](https://github.com/ultralytics/ultralytics/blob/main/pyproject.toml) and check software and hardware.

# %%
# import required libarries and check the environment
import ultralytics
import cv2
from ultralytics import solutions

# Environment checks
ultralytics.checks()
# Out:
# Ultralytics 8.3.95  Python-3.11.9 torch-2.6.0+cpu CPU (13th Gen Intel Core(TM) i7-1365U)
# Setup complete  (12 CPUs, 15.3 GB RAM, 450.8/474.1 GB disk)
# Setup complete  (12 CPUs, 15.3 GB RAM, 450.8/474.1 GB disk)

# %% [markdown]
# ### 1. Counting specific classes of objects

# %% [markdown]
# ##### 1.1 define input path, output path, model, classes to track

# %%
video_path = 'sample-video.mp4'  # Path to your input video file
output_video_path = 'output_specific_classes.avi' # Path to save the output video
model_path = 'yolo11s.pt' # Path to your YOLOv11 model file. 'yolo11n-obb.pt' for OBB detection
classes_to_count = [0, 2, 3]  # Classes to count (0: person, 1: bicycle, 3: car etc.)

# cocoClassNames = ["person", "bicycle", "car", "motorbike", "aeroplane", "bus", "train", "truck", "boat",
#                   "traffic light", "fire hydrant", "stop sign", "parking meter", "bench", "bird", "cat",
#                   "dog", "horse", "sheep", "cow", "elephant", "bear", "zebra", "giraffe", "backpack", "umbrella",
#                   "handbag", "tie", "suitcase", "frisbee", "skis", "snowboard", "sports ball", "kite", "baseball bat",
#                   "baseball glove", "skateboard", "surfboard", "tennis racket", "bottle", "wine glass", "cup",
#                   "fork", "knife", "spoon", "bowl", "banana", "apple", "sandwich", "orange", "broccoli",
#                   "carrot", "hot dog", "pizza", "donut", "cake", "chair", "sofa", "pottedplant", "bed",
#                   "diningtable", "toilet", "tvmonitor", "laptop", "mouse", "remote", "keyboard", "cell phone",
#                   "microwave", "oven", "toaster", "sink", "refrigerator", "book", "clock", "vase", "scissors",
#                   "teddy bear", "hair drier", "toothbrush"
#                   ]

# %% [markdown]
# #### 1.2 Read the Video File
#
# 1. You can either read the video file directly or stream the content from an RTSP (Real-Time Streaming Protocol) source, allowing for flexible video input depending on your needs.
# 2. We will also set up the video writer to handle the output video writing.

# %%
cap = cv2.VideoCapture(video_path)
assert cap.isOpened(), "Error reading video file"
w, h, fps = (int(cap.get(x)) for x in (cv2.CAP_PROP_FRAME_WIDTH, 
                                        cv2.CAP_PROP_FRAME_HEIGHT, 
                                        cv2.CAP_PROP_FPS))
video_writer = cv2.VideoWriter(output_video_path, 
                                cv2.VideoWriter_fourcc(*"mp4v"), 
                                fps, (w, h))

# %% [markdown]
# #### 1.3 Define Region Coordinates
#
# Here, we set the coordinates for specific regions to ensure accurate object tracking and analysis within the video or stream. This helps monitor and track objects effectively in different areas.

# %%
# Define region points
region_points = [(10, 300), (1275, 700)]  # For line tracking
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360)]  # For rectangle region tracking
# region_points = [(20, 400), (1080, 400), (1080, 360), (20, 360), (20, 400)]  # For polygon region tracking

# %% [markdown]
# #### 1.4 Initialize the Object counter Class
#
# Next, let's initialize the object counter class to track objects in each frame of the video.

# %%
# Init ObjectCounter
counter = solutions.ObjectCounter(
    view_image=True, # Display the image during processing
    show=True,  # Display the output
    region=region_points,  # Region of interest points
    model=model_path,  # model="yolo11n-obb.pt" for object counting using YOLO11 OBB model.
    classes=classes_to_count,  # Class names from the YOLO model
    show_in=True,  # Display in counts
    show_out=False,  # Display out counts
    # show_count=True,  # Display count on the video
    # line_width=1,  # Adjust the line width for bounding boxes and text display
    # line_color=(0, 255, 0),  # Adjust the color of the bounding boxes and text display
    line_thickness=2, # Thickness of the lines drawn
    draw_tracks=True,  # Draw tracking lines for objects
)
# Out:
# Ultralytics Solutions:  {'region': [(10, 300), (1275, 700)], 'show_in': True, 'show_out': False, 'colormap': None, 'up_angle': 145.0, 'down_angle': 90, 'kpts': [6, 8, 10], 'analytics_type': 'line', 'json_file': None, 'records': 5, 'view_image': True, 'show': True, 'model': 'yolo11s.pt', 'classes': [0, 2, 3], 'line_thickness': 2, 'draw_tracks': True}

# %% [markdown]
# #### 1.5 Process Video Frames
#
# In this step, we will process each frame of the video to detect and analyze objects. This allows for real-time tracking, based on the visual data in the frames.

# %%
while cap.isOpened():
    success, im0 = cap.read()
    if not success:
        print("Video frame is empty or processing is complete.")
        break
    results = counter(im0)
    video_writer.write(results.plot_im)

cap.release()
video_writer.release()
cv2.destroyAllWindows()

# Print counting results:
# print(f'In: {counter.in_counts}\nOut: {counter.out_counts}\nTotal: {counter.in_counts + counter.out_counts}')
# print(f'Saves output video to {output_video_path}')
# Out:
# 0: 384x640 2 persons, 9 cars, 135.3ms
# Speed: 2.0ms preprocess, 135.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 1 person, 8 cars, 135.2ms
# Speed: 3.2ms preprocess, 135.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 142.9ms
# Speed: 2.3ms preprocess, 142.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 127.0ms
# Speed: 1.3ms preprocess, 127.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 154.2ms
# Speed: 1.7ms preprocess, 154.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 137.5ms
# Speed: 1.4ms preprocess, 137.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 123.2ms
# Speed: 1.5ms preprocess, 123.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(classwise_count={'car': {'IN': 0, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 122.7ms
# Speed: 1.4ms preprocess, 122.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 2 persons, 8 cars, 121.7ms
# Speed: 1.4ms preprocess, 121.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 128.5ms
# Speed: 1.5ms preprocess, 128.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 100.7ms
# Speed: 1.2ms preprocess, 100.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 110.5ms
# Speed: 1.4ms preprocess, 110.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 110.8ms
# Speed: 3.0ms preprocess, 110.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 8 cars, 170.8ms
# Speed: 1.8ms preprocess, 170.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 4 persons, 8 cars, 284.1ms
# Speed: 7.3ms preprocess, 284.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 184.0ms
# Speed: 1.5ms preprocess, 184.0ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 189.1ms
# Speed: 3.1ms preprocess, 189.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 127.7ms
# Speed: 3.5ms preprocess, 127.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 127.8ms
# Speed: 1.2ms preprocess, 127.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 3 persons, 8 cars, 216.5ms
# Speed: 5.0ms preprocess, 216.5ms inference, 2.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 243.8ms
# Speed: 2.8ms preprocess, 243.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 210.1ms
# Speed: 1.2ms preprocess, 210.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 186.2ms
# Speed: 1.8ms preprocess, 186.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 116.1ms
# Speed: 1.3ms preprocess, 116.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 4 persons, 8 cars, 128.9ms
# Speed: 1.4ms preprocess, 128.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 5 persons, 8 cars, 123.8ms
# Speed: 2.3ms preprocess, 123.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 149.3ms
# Speed: 1.5ms preprocess, 149.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 116.0ms
# Speed: 1.6ms preprocess, 116.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 134.4ms
# Speed: 2.1ms preprocess, 134.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 121.0ms
# Speed: 1.3ms preprocess, 121.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 9 cars, 127.1ms
# Speed: 1.2ms preprocess, 127.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 8 cars, 145.1ms
# Speed: 2.1ms preprocess, 145.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 117.9ms
# Speed: 1.6ms preprocess, 117.9ms inference, 2.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 121.9ms
# Speed: 1.5ms preprocess, 121.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 8 cars, 123.6ms
# Speed: 1.7ms preprocess, 123.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 5 persons, 9 cars, 121.6ms
# Speed: 1.5ms preprocess, 121.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 9 cars, 114.3ms
# Speed: 1.5ms preprocess, 114.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 9 cars, 115.3ms
# Speed: 1.7ms preprocess, 115.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=1, classwise_count={'car': {'IN': 1, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 9 cars, 115.7ms
# Speed: 1.5ms preprocess, 115.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 9 cars, 124.7ms
# Speed: 1.6ms preprocess, 124.7ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 9 cars, 114.4ms
# Speed: 1.5ms preprocess, 114.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 5 persons, 8 cars, 101.7ms
# Speed: 1.4ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 4 persons, 8 cars, 102.8ms
# Speed: 1.4ms preprocess, 102.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 115.8ms
# Speed: 1.2ms preprocess, 115.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 124.9ms
# Speed: 1.4ms preprocess, 124.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 4 persons, 8 cars, 137.8ms
# Speed: 1.7ms preprocess, 137.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 3 persons, 7 cars, 114.4ms
# Speed: 1.8ms preprocess, 114.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 7 cars, 125.1ms
# Speed: 2.2ms preprocess, 125.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 7 cars, 104.9ms
# Speed: 2.0ms preprocess, 104.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 7 cars, 112.2ms
# Speed: 1.6ms preprocess, 112.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 8 cars, 107.5ms
# Speed: 1.2ms preprocess, 107.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 101.7ms
# Speed: 1.2ms preprocess, 101.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 98.9ms
# Speed: 1.1ms preprocess, 98.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 99.3ms
# Speed: 1.6ms preprocess, 99.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 8 cars, 235.9ms
# Speed: 1.7ms preprocess, 235.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 2 persons, 8 cars, 99.1ms
# Speed: 1.3ms preprocess, 99.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=2, classwise_count={'car': {'IN': 2, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 109.1ms
# Speed: 1.8ms preprocess, 109.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 2 persons, 8 cars, 102.4ms
# Speed: 1.7ms preprocess, 102.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 8 cars, 104.6ms
# Speed: 1.1ms preprocess, 104.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 3 persons, 7 cars, 114.1ms
# Speed: 1.3ms preprocess, 114.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 7 cars, 113.3ms
# Speed: 1.2ms preprocess, 113.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 3 persons, 7 cars, 116.2ms
# Speed: 1.4ms preprocess, 116.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 1 person, 7 cars, 90.6ms
# Speed: 1.1ms preprocess, 90.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 1 person, 8 cars, 109.5ms
# Speed: 1.1ms preprocess, 109.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 95.4ms
# Speed: 1.4ms preprocess, 95.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 106.2ms
# Speed: 1.5ms preprocess, 106.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 1 person, 8 cars, 101.8ms
# Speed: 1.4ms preprocess, 101.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 8 cars, 114.2ms
# Speed: 1.4ms preprocess, 114.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 107.7ms
# Speed: 1.4ms preprocess, 107.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 99.0ms
# Speed: 2.2ms preprocess, 99.0ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 118.6ms
# Speed: 1.3ms preprocess, 118.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 103.6ms
# Speed: 1.4ms preprocess, 103.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=3, classwise_count={'car': {'IN': 3, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 106.6ms
# Speed: 1.2ms preprocess, 106.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 123.6ms
# Speed: 1.4ms preprocess, 123.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 128.7ms
# Speed: 1.6ms preprocess, 128.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 120.1ms
# Speed: 1.8ms preprocess, 120.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 108.4ms
# Speed: 1.4ms preprocess, 108.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 7 cars, 118.5ms
# Speed: 1.4ms preprocess, 118.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 113.8ms
# Speed: 1.7ms preprocess, 113.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=4, classwise_count={'car': {'IN': 4, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 117.5ms
# Speed: 1.5ms preprocess, 117.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 8 cars, 95.2ms
# Speed: 1.2ms preprocess, 95.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 113.4ms
# Speed: 1.3ms preprocess, 113.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 118.7ms
# Speed: 1.2ms preprocess, 118.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 125.7ms
# Speed: 1.5ms preprocess, 125.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 105.3ms
# Speed: 1.8ms preprocess, 105.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 119.3ms
# Speed: 1.3ms preprocess, 119.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 7 cars, 110.2ms
# Speed: 1.7ms preprocess, 110.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 111.7ms
# Speed: 2.2ms preprocess, 111.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 7 cars, 111.1ms
# Speed: 1.3ms preprocess, 111.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=7)
#
# 0: 384x640 8 cars, 114.7ms
# Speed: 1.7ms preprocess, 114.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 115.6ms
# Speed: 1.4ms preprocess, 115.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 100.5ms
# Speed: 1.5ms preprocess, 100.5ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 96.1ms
# Speed: 1.4ms preprocess, 96.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 104.9ms
# Speed: 1.5ms preprocess, 104.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 122.3ms
# Speed: 1.2ms preprocess, 122.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=5, classwise_count={'car': {'IN': 5, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 121.5ms
# Speed: 1.4ms preprocess, 121.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 132.7ms
# Speed: 1.3ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 118.4ms
# Speed: 1.8ms preprocess, 118.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 136.1ms
# Speed: 1.4ms preprocess, 136.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 8 cars, 124.2ms
# Speed: 1.3ms preprocess, 124.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 9 cars, 126.1ms
# Speed: 2.2ms preprocess, 126.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 125.9ms
# Speed: 1.8ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 131.5ms
# Speed: 1.5ms preprocess, 131.5ms inference, 3.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 123.4ms
# Speed: 1.3ms preprocess, 123.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 121.4ms
# Speed: 1.3ms preprocess, 121.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 122.3ms
# Speed: 1.4ms preprocess, 122.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 124.6ms
# Speed: 1.7ms preprocess, 124.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 119.8ms
# Speed: 1.5ms preprocess, 119.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 8 cars, 119.5ms
# Speed: 1.6ms preprocess, 119.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=8)
#
# 0: 384x640 11 cars, 118.3ms
# Speed: 1.5ms preprocess, 118.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 12 cars, 120.4ms
# Speed: 1.7ms preprocess, 120.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 14 cars, 109.1ms
# Speed: 1.3ms preprocess, 109.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 14 cars, 99.0ms
# Speed: 1.2ms preprocess, 99.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=14)
#
# 0: 384x640 15 cars, 104.9ms
# Speed: 1.2ms preprocess, 104.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=15)
#
# 0: 384x640 13 cars, 111.1ms
# Speed: 1.2ms preprocess, 111.1ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 13 cars, 126.5ms
# Speed: 1.9ms preprocess, 126.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=13)
#
# 0: 384x640 12 cars, 113.6ms
# Speed: 1.2ms preprocess, 113.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 126.6ms
# Speed: 1.8ms preprocess, 126.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 120.1ms
# Speed: 1.6ms preprocess, 120.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 130.2ms
# Speed: 3.3ms preprocess, 130.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 97.3ms
# Speed: 1.3ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 97.0ms
# Speed: 1.2ms preprocess, 97.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 11 cars, 120.0ms
# Speed: 2.1ms preprocess, 120.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 102.3ms
# Speed: 1.3ms preprocess, 102.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 101.3ms
# Speed: 1.4ms preprocess, 101.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 141.5ms
# Speed: 1.2ms preprocess, 141.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 11 cars, 116.1ms
# Speed: 1.4ms preprocess, 116.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 112.3ms
# Speed: 1.5ms preprocess, 112.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 130.2ms
# Speed: 1.5ms preprocess, 130.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 137.3ms
# Speed: 1.9ms preprocess, 137.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 132.8ms
# Speed: 1.3ms preprocess, 132.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 109.3ms
# Speed: 1.2ms preprocess, 109.3ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 116.1ms
# Speed: 1.2ms preprocess, 116.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 115.3ms
# Speed: 1.5ms preprocess, 115.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 112.1ms
# Speed: 1.2ms preprocess, 112.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 117.9ms
# Speed: 1.4ms preprocess, 117.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 111.0ms
# Speed: 1.7ms preprocess, 111.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 117.2ms
# Speed: 1.7ms preprocess, 117.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 121.5ms
# Speed: 1.3ms preprocess, 121.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 130.3ms
# Speed: 1.3ms preprocess, 130.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 11 cars, 134.1ms
# Speed: 1.4ms preprocess, 134.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=6, classwise_count={'car': {'IN': 6, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 132.3ms
# Speed: 1.5ms preprocess, 132.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=7, classwise_count={'car': {'IN': 7, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 129.8ms
# Speed: 1.5ms preprocess, 129.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=7, classwise_count={'car': {'IN': 7, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 151.8ms
# Speed: 1.6ms preprocess, 151.8ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=7, classwise_count={'car': {'IN': 7, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 137.5ms
# Speed: 1.2ms preprocess, 137.5ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=7, classwise_count={'car': {'IN': 7, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 129.7ms
# Speed: 1.2ms preprocess, 129.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=7, classwise_count={'car': {'IN': 7, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 123.4ms
# Speed: 1.6ms preprocess, 123.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 107.3ms
# Speed: 1.3ms preprocess, 107.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 9 cars, 127.0ms
# Speed: 1.3ms preprocess, 127.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 125.0ms
# Speed: 1.9ms preprocess, 125.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 10 cars, 132.7ms
# Speed: 1.9ms preprocess, 132.7ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 135.6ms
# Speed: 2.4ms preprocess, 135.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 126.0ms
# Speed: 1.5ms preprocess, 126.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 126.0ms
# Speed: 1.8ms preprocess, 126.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 107.0ms
# Speed: 1.2ms preprocess, 107.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 101.7ms
# Speed: 1.2ms preprocess, 101.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 100.6ms
# Speed: 1.4ms preprocess, 100.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 9 cars, 114.1ms
# Speed: 1.2ms preprocess, 114.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 99.0ms
# Speed: 1.3ms preprocess, 99.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 113.4ms
# Speed: 1.2ms preprocess, 113.4ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 111.3ms
# Speed: 1.9ms preprocess, 111.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 123.9ms
# Speed: 2.7ms preprocess, 123.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 101.1ms
# Speed: 1.4ms preprocess, 101.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 10 cars, 117.6ms
# Speed: 1.4ms preprocess, 117.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 139.9ms
# Speed: 1.5ms preprocess, 139.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 9 cars, 143.3ms
# Speed: 1.6ms preprocess, 143.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 127.4ms
# Speed: 1.4ms preprocess, 127.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 126.8ms
# Speed: 1.3ms preprocess, 126.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 130.8ms
# Speed: 1.5ms preprocess, 130.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 145.1ms
# Speed: 2.0ms preprocess, 145.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 120.8ms
# Speed: 1.6ms preprocess, 120.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 133.3ms
# Speed: 2.0ms preprocess, 133.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 10 cars, 125.6ms
# Speed: 1.6ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 124.3ms
# Speed: 1.6ms preprocess, 124.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 9 cars, 124.8ms
# Speed: 1.5ms preprocess, 124.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 124.9ms
# Speed: 1.3ms preprocess, 124.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 124.7ms
# Speed: 1.8ms preprocess, 124.7ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 135.2ms
# Speed: 1.9ms preprocess, 135.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 125.2ms
# Speed: 1.3ms preprocess, 125.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 118.9ms
# Speed: 1.5ms preprocess, 118.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 128.8ms
# Speed: 1.3ms preprocess, 128.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 117.1ms
# Speed: 1.4ms preprocess, 117.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 150.4ms
# Speed: 1.3ms preprocess, 150.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=8, classwise_count={'car': {'IN': 8, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=9)
#
# 0: 384x640 9 cars, 126.9ms
# Speed: 2.0ms preprocess, 126.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
# ...
#
# 0: 384x640 12 cars, 122.1ms
# Speed: 1.2ms preprocess, 122.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=12, classwise_count={'car': {'IN': 12, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 128.7ms
# Speed: 1.6ms preprocess, 128.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 119.5ms
# Speed: 2.3ms preprocess, 119.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 12 cars, 112.2ms
# Speed: 1.3ms preprocess, 112.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=12)
#
# 0: 384x640 11 cars, 127.1ms
# Speed: 1.8ms preprocess, 127.1ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 127.6ms
# Speed: 1.3ms preprocess, 127.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 115.9ms
# Speed: 1.3ms preprocess, 115.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 115.1ms
# Speed: 1.5ms preprocess, 115.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 125.9ms
# Speed: 1.2ms preprocess, 125.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 120.6ms
# Speed: 1.5ms preprocess, 120.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 123.8ms
# Speed: 1.4ms preprocess, 123.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 129.7ms
# Speed: 1.7ms preprocess, 129.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 107.6ms
# Speed: 1.4ms preprocess, 107.6ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 107.2ms
# Speed: 1.3ms preprocess, 107.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 113.2ms
# Speed: 1.2ms preprocess, 113.2ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 116.4ms
# Speed: 1.3ms preprocess, 116.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 137.2ms
# Speed: 1.7ms preprocess, 137.2ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 110.4ms
# Speed: 1.3ms preprocess, 110.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 132.8ms
# Speed: 1.5ms preprocess, 132.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 104.8ms
# Speed: 1.2ms preprocess, 104.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 112.6ms
# Speed: 1.3ms preprocess, 112.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 136.6ms
# Speed: 1.8ms preprocess, 136.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 106.1ms
# Speed: 1.8ms preprocess, 106.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 120.1ms
# Speed: 1.2ms preprocess, 120.1ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 108.4ms
# Speed: 2.8ms preprocess, 108.4ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 110.9ms
# Speed: 1.5ms preprocess, 110.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 99.7ms
# Speed: 1.3ms preprocess, 99.7ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 101.1ms
# Speed: 1.1ms preprocess, 101.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 120.4ms
# Speed: 1.3ms preprocess, 120.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 106.6ms
# Speed: 1.4ms preprocess, 106.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 100.3ms
# Speed: 1.3ms preprocess, 100.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 97.6ms
# Speed: 1.1ms preprocess, 97.6ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 109.7ms
# Speed: 1.2ms preprocess, 109.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 120.4ms
# Speed: 1.2ms preprocess, 120.4ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 139.9ms
# Speed: 3.3ms preprocess, 139.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 124.8ms
# Speed: 1.6ms preprocess, 124.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 124.9ms
# Speed: 1.5ms preprocess, 124.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 102.5ms
# Speed: 1.3ms preprocess, 102.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 113.6ms
# Speed: 2.2ms preprocess, 113.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 119.3ms
# Speed: 1.5ms preprocess, 119.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 122.5ms
# Speed: 1.6ms preprocess, 122.5ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 124.0ms
# Speed: 1.5ms preprocess, 124.0ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 134.7ms
# Speed: 1.6ms preprocess, 134.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 120.2ms
# Speed: 2.2ms preprocess, 120.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=13, classwise_count={'car': {'IN': 13, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 134.7ms
# Speed: 1.4ms preprocess, 134.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=14, classwise_count={'car': {'IN': 14, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 110.1ms
# Speed: 2.0ms preprocess, 110.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=14, classwise_count={'car': {'IN': 14, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 116.9ms
# Speed: 1.5ms preprocess, 116.9ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=14, classwise_count={'car': {'IN': 14, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 11 cars, 122.5ms
# Speed: 1.3ms preprocess, 122.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 129.9ms
# Speed: 1.4ms preprocess, 129.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 122.8ms
# Speed: 1.7ms preprocess, 122.8ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 139.1ms
# Speed: 1.8ms preprocess, 139.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 11 cars, 127.9ms
# Speed: 1.3ms preprocess, 127.9ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 125.9ms
# Speed: 1.5ms preprocess, 125.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=15, classwise_count={'car': {'IN': 15, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 11 cars, 127.8ms
# Speed: 1.5ms preprocess, 127.8ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 128.3ms
# Speed: 1.8ms preprocess, 128.3ms inference, 0.8ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 136.2ms
# Speed: 1.4ms preprocess, 136.2ms inference, 0.9ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 121.8ms
# Speed: 1.5ms preprocess, 121.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 119.9ms
# Speed: 1.9ms preprocess, 119.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 11 cars, 116.2ms
# Speed: 1.3ms preprocess, 116.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=11)
#
# 0: 384x640 10 cars, 141.4ms
# Speed: 1.3ms preprocess, 141.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)
#
# 0: 384x640 10 cars, 138.4ms
# Speed: 1.7ms preprocess, 138.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
#  Results: SolutionResults(in_count=16, classwise_count={'car': {'IN': 16, 'OUT': 0}, 'person': {'IN': 0, 'OUT': 0}}, total_tracks=10)

# %% [markdown]
# ### Live stream
